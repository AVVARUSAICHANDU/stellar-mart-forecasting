# %%
import streamlit as st
import pandas as pd
import joblib
import plotly.express as px

st.set_page_config(
    page_title="StellarMart Sales Dashboard",
    layout="wide"
)

# ===== LOAD DATA =====
@st.cache_data
def load_daily_sales():
    daily = pd.read_csv("data/daily_sales.csv")
    daily["transaction_date"] = pd.to_datetime(daily["transaction_date"])
    return daily

# Load data
daily = load_daily_sales()

# ===== KPIs =====
total_sales = daily["daily_sales"].sum()
avg_sales = daily["daily_sales"].mean()
peak_day = daily.loc[daily["daily_sales"].idxmax(), "transaction_date"]

# Convert peak day to safe string format for Streamlit
try:
    peak_day_str = peak_day.strftime("%Y-%m-%d")
except:
    peak_day_str = str(peak_day)

# ===== TITLE =====
st.title("📊 StellarMart Sales Forecasting Dashboard")

col1, col2, col3 = st.columns(3)
col1.metric("Total Sales", f"${total_sales:,.0f}")
col2.metric("Avg Daily Sales", f"${avg_sales:,.0f}")
col3.metric("Peak Sales Day", peak_day_str)

st.markdown("---")

# ===== DAILY SALES CHART =====
fig1 = px.line(
    daily,
    x="transaction_date",
    y="daily_sales",
    title="📈 Daily Sales Over Time"
)
st.plotly_chart(fig1, use_container_width=True)

# ===== LOAD MODEL =====
try:
    model = joblib.load("models/sales_model.pkl")
    st.success("Model Loaded Successfully")
except:
    st.error("⚠️ Model file not found. Please train the model first.")
    st.stop()

# ===== FORECAST SECTION =====
st.header("🔮 14-Day Sales Forecast")

if st.button("Generate Forecast"):
    last_day_number = len(daily)
    future_days = pd.DataFrame({"day_number": range(last_day_number, last_day_number + 14)})

    forecast = model.predict(future_days)

    forecast_df = pd.DataFrame({
        "day": range(1, 15),
        "forecasted_sales": forecast
    })

    fig2 = px.bar(
        forecast_df,
        x="day",
        y="forecasted_sales",
        title="📅 14-Day Forecasted Sales"
    )
    st.plotly_chart(fig2, use_container_width=True)

    st.write("### 📄 Forecast Data")
    st.dataframe(forecast_df)

else:
    st.info("⬆️ Click the button above to generate the forecast.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
# ----> 5 import seaborn as sns
#       7 # STEP 2 — Load your Excel file from the data folder
#       8 path = "data/StellarMart_Raw_Dataset_final.xlsx"
#
# File c:\Users\saich\OneDrive\Documents\stellar-mart-forecasting\.venv\Lib\site-packages\seaborn\__init__.py:5
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
# ----> 5 from .relational import *  # noqa: F401,F403
#       6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
#
# File c:\Users\saich\OneDrive\Documents\stellar-mart-forecasting\.venv\Lib\site-packages\seaborn\relational.py:21
#      13 from .utils import (
#      14     adjust_legend_subtitles,
#      15     _default_color,
#    (...)     18     _scatter_legend_artist,
#      19 )
#      20 from ._compat import groupby_apply_include_groups
# ---> 21 from ._statistics import EstimateAggregator, WeightedAggregator
#      22 from .axisgrid import FacetGrid, _facet_docs
#      23 from ._docstrings import DocstringComponents, _core_docs
#
# File c:\Users\saich\OneDrive\Documents\stellar-mart-forecasting\.venv\Lib\site-packages\seaborn\_statistics.py:32
#      30 import pandas as pd
#      31 try:
# ---> 32     from scipy.stats import gaussian_kde
#      33     _no_scipy = False
#      34 except ImportError:
#
# File c:\Users\saich\OneDrive\Documents\stellar-mart-forecasting\.venv\Lib\site-packages\scipy\stats\__init__.py:626
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    621
#     622 """  # noqa: E501
#     624 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     625                                DegenerateDataWarning, FitError)
# --> 626 from ._stats_py import *
#     627 from ._variation import variation
#     628 from .distributions import *
#
# File c:\Users\saich\OneDrive\Documents\stellar-mart-forecasting\.venv\Lib\site-packages\scipy\stats\_stats_py.py:52
#      49 # Import unused here but needs to stay until end of deprecation periode
#      50 # See https://github.com/scipy/scipy/issues/15765#issuecomment-1875564522
#      51 from scipy import linalg  # noqa: F401
# ---> 52 from . import distributions
#      53 from . import _mstats_basic as mstats_basic
#      55 from ._stats_mstats_common import _find_repeats, theilslopes, siegelslopes
#
# File c:\Users\saich\OneDrive\Documents\stellar-mart-forecasting\.venv\Lib\site-packages\scipy\stats\distributions.py:10
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)      6 #       instead of `git blame -Lxxx,+x`.
#       7 #
#       8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
# ---> 10 from . import _continuous_distns
#      11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
#
# File c:\Users\saich\OneDrive\Documents\stellar-mart-forecasting\.venv\Lib\site-packages\scipy\stats\_continuous_distns.py:13
#      11 import numpy as np
#      12 from numpy.polynomial import Polynomial
# ---> 13 from scipy.interpolate import BSpline
#      14 from scipy._lib.doccer import (extend_notes_in_docstring,
#      15                                replace_notes_in_docstring,
#      16                                inherit_docstring_from)
#      17 from scipy._lib._ccallback import LowLevelCallable
#
# File c:\Users\saich\OneDrive\Documents\stellar-mart-forecasting\.venv\Lib\site-packages\scipy\interpolate\__init__.py:192
#       1 """
#       2 ========================================
#       3 Interpolation (:mod:`scipy.interpolate`)
#    (...)    190
#     191 """  # noqa: E501
# --> 192 from ._interpolate import *
#     193 from ._fitpack_py import *
#     195 from ._fitpack2 import *
#
# File c:\Users\saich\OneDrive\Documents\stellar-mart-forecasting\.venv\Lib\site-packages\scipy\interpolate\_interpolate.py:15
#      13 from ._polyint import _Interpolator1D
#      14 from . import _ppoly
# ---> 15 from ._interpnd import _ndim_coords_from_arrays
#      16 from ._bsplines import make_interp_spline, BSpline
#      19 def lagrange(x, w):
#
# File <frozen importlib._bootstrap>:645, in parent(self)
#
# KeyboardInterrupt:
